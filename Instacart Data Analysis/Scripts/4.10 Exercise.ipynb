# %%
#importing libraries
import pandas as pd
import numpy as np
import os

# %%
#creating path
path = r'C:\Users\haari\OneDrive\Documents\Instacart Basket Analysis'

# %%
#importing latest data frame
ords_prods_cust_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Processed Data', 'ords_prods_cust_merge.pkl'))

# %%
#check the output
ords_prods_cust_merge.shape
# Out:
# (32435059, 31)

# %%
ords_prods_cust_merge.head()
# Out:
#    order_id user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329       1    prior             1          2                  8
# 1   2539329       1    prior             1          2                  8
# 2   2539329       1    prior             1          2                  8
# 3   2539329       1    prior             1          2                  8
# 4   2539329       1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  ...  \
# 0                     NaN         196                  1          0  ...
# 1                     NaN       14084                  2          0  ...
# 2                     NaN       12427                  3          0  ...
# 3                     NaN       26088                  4          0  ...
# 4                     NaN       26405                  5          0  ...
#
#   frequency         frequency_flag  first_name  last_name  gender    state  \
# 0      20.5  Non-Frequent customer       Linda     Nguyen  Female  Alabama
# 1      20.5  Non-Frequent customer       Linda     Nguyen  Female  Alabama
# 2      20.5  Non-Frequent customer       Linda     Nguyen  Female  Alabama
# 3      20.5  Non-Frequent customer       Linda     Nguyen  Female  Alabama
# 4      20.5  Non-Frequent customer       Linda     Nguyen  Female  Alabama
#
#   age  date_joined num_of_dependants  income
# 0  31    2/17/2019                 3   40423
# 1  31    2/17/2019                 3   40423
# 2  31    2/17/2019                 3   40423
# 3  31    2/17/2019                 3   40423
# 4  31    2/17/2019                 3   40423
#
# [5 rows x 31 columns]

# %%
#crosstab between 'days_since_prior_order' and 'order_number'
crosstab = pd.crosstab(ords_prods_cust_merge['days_since_prior_order'], ords_prods_cust_merge['order_number'], dropna = False)

# %%
#copying the crosstab table to clipboard
crosstab.to_clipboard()
